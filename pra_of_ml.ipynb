# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadFarhan96/AiML-Project/blob/main/pra_of_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
np.random.seed(42)
cgpa = np.random.uniform(1.0, 4.0, 100)
iq = np.random.uniform(90, 130, 100)

# %%
placement = (0.7 * cgpa + 0.3 * (iq/40) > 2.5).astype(int)

df = pd.DataFrame({'CGPA': cgpa, 'IQ': iq, 'Placement': placement})
df.head()
# Out:
#        CGPA          IQ  Placement
# 0  2.123620   91.257167          0
# 1  3.852143  115.456416          1
# 2  3.195982  102.574239          1
# 3  2.795975  110.342828          1
# 4  1.468056  126.302659          0

# %%
X = df[['CGPA', 'IQ']]
y = df['Placement']
df.head()
# Out:
#        CGPA          IQ  Placement
# 0  2.123620   91.257167          0
# 1  3.852143  115.456416          1
# 2  3.195982  102.574239          1
# 3  2.795975  110.342828          1
# 4  1.468056  126.302659          0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
print(f"Project Accuracy: {accuracy_score(y_test, y_pred)*100}%")
# Out:
# Project Accuracy: 90.0%

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=model, legend=2)
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.title('Placement Prediction Decision Boundary')
plt.savefig('placement_plot.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
